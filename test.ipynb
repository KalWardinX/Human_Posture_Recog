# %%
import joblib
import sklearn

clf = joblib.load("/home/akash/data/btech/Project/final/Aasana/models/knn2.joblib")

# %%
import cv2
import mediapipe as mp
import numpy as np

# %%
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
def preprocessing1(detection_result):
    joint = {}
    joint['head'] = [0,
                     [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.NOSE.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.NOSE.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.NOSE.value].z]
    ]
    joint['neck'] = [1,
                     [(detection_result.pose_landmarks[0][mp_pose.PoseLandmark.NOSE.value].x + detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_SHOULDER.value].x + detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x)/3,
                     (detection_result.pose_landmarks[0][mp_pose.PoseLandmark.NOSE.value].y + detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_SHOULDER.value].y + detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y)/3,
                     (detection_result.pose_landmarks[0][mp_pose.PoseLandmark.NOSE.value].z + detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_SHOULDER.value].z + detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_SHOULDER.value].z)/3]
    ]
    joint['shoulder_left'] = [2,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_SHOULDER.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_SHOULDER.value].z]
    ]
    joint['shoulder_right'] = [3,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_SHOULDER.value].z]
    ]
    joint['elbow_left'] = [4,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_ELBOW.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_ELBOW.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_ELBOW.value].z]
    ]
    joint['elbow_right'] = [5,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_ELBOW.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_ELBOW.value].z]
    ]
    joint['wrist_left'] = [6,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_WRIST.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_WRIST.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_WRIST.value].z]
    ]
    joint['wrist_right'] = [7,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_WRIST.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_WRIST.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_WRIST.value].z]
    ]
    joint['palm_left'] = [8,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_INDEX.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_INDEX.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_INDEX.value].z]
    ]
    joint['palm_right'] = [9,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_INDEX.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_INDEX.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_INDEX.value].z]
    ]
    joint['hip_left'] = [10,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_HIP.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_HIP.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_HIP.value].z]
    ]
    joint['hip_right'] = [11,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_HIP.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_HIP.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_HIP.value].z]
    ]
    joint['knee_left'] = [12,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_KNEE.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_KNEE.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_KNEE.value].z]
    ]
    joint['knee_right'] = [13,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_KNEE.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_KNEE.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_KNEE.value].z]
    ]
    joint['ankle_left'] = [14,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_ANKLE.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_ANKLE.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_ANKLE.value].z]
    ]
    joint['ankle_right'] = [15,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_ANKLE.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_ANKLE.value].z]
    ]
    joint['foot_left'] = [16,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_FOOT_INDEX.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_FOOT_INDEX.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.LEFT_FOOT_INDEX.value].z]
    ]
    joint['foot_right'] = [17,
                      [detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_FOOT_INDEX.value].x,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_FOOT_INDEX.value].y,
                     detection_result.pose_landmarks[0][mp_pose.PoseLandmark.RIGHT_FOOT_INDEX.value].z]
    ]
    return joint

# %%
def distance_feature(position1, position2):
    #calculating vector 
    x_diff = position2[0] - position1[0]
    y_diff = position2[1] - position1[1]
    z_diff = position2[2] - position1[2]
    return (x_diff,y_diff,z_diff)

def calculate_angle(segment1,segment2):
    # Calculate the angle between three joints in radians
    dot_product = segment1[0] * segment2[0] + segment1[1] * segment2[1] + segment1[2] * segment2[2]
    magnitude_product = math.sqrt(segment1[0]**2+segment1[1]**2+segment1[2]**2)*math.sqrt(segment2[0]**2+segment2[1]**2+segment2[2]**2)
    angle = math.acos(dot_product / magnitude_product)
    return angle

# %%
def preprocessing2(data):
    joint_positions={}
    joint_positions = {
        'Head': [data['head'][1][0], data['head'][1][1], data['head'][1][2]],
        'Neck': [data['neck'][1][0], data['neck'][1][1], data['neck'][1][2]],
        'ShoulderLeft': [data['shoulder_left'][1][0], data['shoulder_left'][1][1], data['shoulder_left'][1][2]],
        'ElbowLeft': [data['elbow_left'][1][0], data['elbow_left'][1][1], data['elbow_left'][1][2]],
        'WristLeft': [data['wrist_left'][1][0], data['wrist_left'][1][1], data['wrist_left'][1][2]],
        'HandLeft': [data['palm_left'][1][0], data['palm_left'][1][1], data['palm_left'][1][2]],
        'ShoulderRight': [data['shoulder_right'][1][0], data['shoulder_right'][1][1], data['shoulder_right'][1][2]],
        'ElbowRight': [data['elbow_right'][1][0], data['elbow_right'][1][1], data['elbow_right'][1][2]],
        'WristRight': [data['wrist_right'][1][0], data['wrist_right'][1][1], data['wrist_right'][1][2]],
        'HandRight': [data['palm_right'][1][0], data['palm_right'][1][1], data['palm_right'][1][2]],
        'HipLeft': [data['hip_left'][1][0], data['hip_left'][1][1], data['hip_left'][1][2]],
        'KneeLeft': [data['knee_left'][1][0], data['knee_left'][1][1], data['knee_left'][1][2]],
        'AnkleLeft': [data['ankle_left'][1][0], data['ankle_left'][1][1], data['ankle_left'][1][2]],
        'FootLeft': [data['foot_left'][1][0], data['foot_left'][1][1], data['foot_left'][1][2]],
        'HipRight': [data['hip_right'][1][0], data['hip_right'][1][1], data['hip_right'][1][2]],
        'KneeRight': [data['knee_right'][1][0], data['knee_right'][1][1], data['knee_right'][1][2]],
        'AnkleRight': [data['ankle_right'][1][0], data['ankle_right'][1][1], data['ankle_right'][1][2]],
        'FootRight': [data['foot_right'][1][0], data['foot_right'][1][1], data['foot_right'][1][2]]
    }
    joint_pairs = [
        ['Head', 'Neck'],
        ['Neck', 'ShoulderLeft'],
        ['Neck', 'ShoulderRight'],
        ['ShoulderLeft', 'ShoulderRight'],
        ['ShoulderLeft', 'ElbowLeft'],
        ['ElbowLeft', 'WristLeft'],
        ['WristLeft', 'HandLeft'],
        ['ShoulderRight', 'ElbowRight'],
        ['ElbowRight', 'WristRight'],
        ['WristRight', 'HandRight'],
        ['ShoulderLeft', 'WristLeft'],
        ['ShoulderRight', 'WristRight'],
        ['ShoulderLeft', 'HipLeft'],
        ['ShoulderRight', 'HipRight'],
        ['HipLeft', 'KneeLeft'],
        ['HipRight', 'KneeRight'],
        ['KneeLeft', 'AnkleLeft'],
        ['KneeRight', 'AnkleRight'],
        ['AnkleLeft', 'FootLeft'],
        ['AnkleRight', 'FootRight'],
        ['HipLeft', 'HipRight'],
        ['HipLeft', 'AnkleLeft'],
        ['HipRight', 'AnkleRight'],
        ['FootLeft', 'FootRight']
    ]

    distance_vectors = []
    for pair in joint_pairs:
        joint1 = pair[0]
        joint2 = pair[1]
        vector = distance_feature( joint_positions[joint1], joint_positions[joint2])
        distance_vectors.append(vector)
    
    angle_features = []

    for segment1 in range(0,len(distance_vectors)):
      for segment2 in range(0,len(distance_vectors)):
        if(segment1>segment2):
            angle_features.append(calculate_angle(distance_vectors[segment1],distance_vectors[segment2]))
    
    joint_features= []
    joint_features += data['head'][1]
    joint_features += data['neck'][1]
    joint_features += data['shoulder_left'][1]
    joint_features += data['shoulder_right'][1]
    joint_features += data['elbow_left'][1]
    joint_features += data['elbow_right'][1]
    joint_features += data['wrist_left'][1]
    joint_features += data['wrist_right'][1]
    joint_features += data['palm_left'][1]
    joint_features += data['palm_right'][1]
    joint_features += data['hip_left'][1]
    joint_features += data['hip_right'][1]
    joint_features += data['knee_left'][1]
    joint_features += data['knee_right'][1]
    joint_features += data['ankle_left'][1]
    joint_features += data['ankle_right'][1]
    joint_features += data['foot_left'][1]
    joint_features += data['foot_right'][1]
    distance_measures=[]
    
    distance_features = [
        ['Head', 'Neck'],
        ['Neck', 'ShoulderLeft'],
        ['Neck', 'ShoulderRight'],
        ['ShoulderLeft', 'ShoulderRight'],
        ['ShoulderLeft', 'ElbowLeft'],
        ['ElbowLeft', 'WristLeft'],
        ['WristLeft', 'HandLeft'],
        ['ShoulderRight', 'ElbowRight'],
        ['ElbowRight', 'WristRight'],
        ['WristRight', 'HandRight'],
        ['ShoulderLeft', 'WristLeft'],
        ['ShoulderRight', 'WristRight'],
        ['ShoulderLeft', 'HipLeft'],
        ['ShoulderRight', 'HipRight'],
        ['HipLeft', 'KneeLeft'],
        ['HipRight', 'KneeRight'],
        ['KneeLeft', 'AnkleLeft'],
        ['KneeRight', 'AnkleRight'],
        ['AnkleLeft', 'FootLeft'],
        ['AnkleRight', 'FootRight'],
        ['HipLeft', 'HipRight'],
        ['HipLeft', 'AnkleLeft'],
        ['HipRight', 'AnkleRight'],
        ['FootLeft', 'FootRight'],
        ['Head','HandLeft'],
        ['Head','HandRight'],
        ['HandLeft','HipRight'],
        ['HandRight','HipLeft'],
        ['FootRight','HipLeft'],
        ['FootLeft','HipRight'],
        ['Head','HipLeft'],
        ['Head','HipRight']
    ]
    for point in distance_features:
        joint1 = joint_positions[point[0]]
        joint2 = joint_positions[point[1]]
        distance = math.sqrt((joint2[0] - joint1[0]) ** 2 + (joint2[1] - joint1[1]) ** 2 + (joint2[2] - joint1[2]) ** 2)
        distance_measures.append(distance)
        
    return joint_features + distance_measures+angle_features

# %%
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
import numpy as np


def draw_landmarks_on_image(rgb_image, detection_result):
  pose_landmarks_list = detection_result.pose_landmarks
  annotated_image = np.copy(rgb_image)

  # Loop through the detected poses to visualize.
  for idx in range(len(pose_landmarks_list)):
    pose_landmarks = pose_landmarks_list[idx]

    # Draw the pose landmarks.
    pose_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
    pose_landmarks_proto.landmark.extend([
      landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in pose_landmarks
    ])
    solutions.drawing_utils.draw_landmarks(
      annotated_image,
      pose_landmarks_proto,
      solutions.pose.POSE_CONNECTIONS,
      solutions.drawing_styles.get_default_pose_landmarks_style())
  return annotated_image

# %%
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import os
import cv2
import json
import pandas as pd
import math
import numpy as np


#Initialize mediapipe pose class.
mp_pose = mp.solutions.pose

# Setup the Pose function for images - independently for the images standalone processing.
# pose_image = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)

# Initialize mediapipe drawing class - to draw the landmarks points.
mp_drawing = mp.solutions.drawing_utils
d = [
    'downdog',
    'Bitilasana',
    'tree',
    'Salamba_Sarvangasana',
    'Vasisthasana',
    'warrior'
]

# STEP 2: Create an PoseLandmarker object.
base_options = python.BaseOptions(model_asset_path='pose_landmarker.task')
options = vision.PoseLandmarkerOptions(
    base_options=base_options,
    output_segmentation_masks=True)
detector = vision.PoseLandmarker.create_from_options(options)
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, image = cap.read()
    if not ret:
        print(ret)
        break
    image1 = image
    cv2.imwrite('./image.jpg',image)
    image = mp.Image.create_from_file('image.jpg')
    detection_result = detector.detect(image)
    if detection_result.pose_landmarks == []:
        continue
    # get pose
    #pose_detected = get_pose(result.pose_landmarks)
    
    image1.flags.writeable = True;
#     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    image1 = draw_landmarks_on_image(image1, detection_result)
#     mp_drawing.draw_landmarks(image, detection_result.pose_landmarks, mp_pose.POSE_CONNECTIONS)
    joint = preprocessing1(detection_result)
    data = preprocessing2(joint)
    df = pd.DataFrame([data], columns=[f'X{i}' for i in range(1,363)])
    pred = clf.predict(df)
    res = pred[0]
    font = cv2.FONT_HERSHEY_SIMPLEX
  
    # org
    org = (50, 50)

    # fontScale
    fontScale = 1

    # Blue color in BGR
    color = (255, 0, 0)

    # Line thickness of 2 px
    thickness = 2
    # Using cv2.putText() method
    image = cv2.putText(image1, d[res], org, font, fontScale, color, thickness, cv2.LINE_AA)
    cv2.imshow('mediapipe feed', image)

    if cv2.waitKey(10) & 0xff == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
